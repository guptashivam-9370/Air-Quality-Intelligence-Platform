# %% [markdown]
# # Air Quality Prediction using LSTM

# %% [markdown]
# - ### **This notebook implements a Long Short-Term Memory (LSTM) neural network model to predict air quality pollutant levels based on historical data.**

# %% [markdown]
# ## Import Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import json

# %% [markdown]
# ## Configuration Parameters

# %%
# Configuration parameters
SEQUENCE_LENGTH = 7  # Number of days to use for prediction
POLLUTANTS = ['pm2_5', 'pm10', 'so2', 'no', 'no2', 'nh3', 'o3', 'co']
TEST_SPLIT = 0.2  # Proportion of data to use for testing
MODEL_PARAMS = {
    'lstm_units': 64,
    'dropout_rate': 0.2,
    'epochs': 50,
    'batch_size': 32,
    'patience': 10
}

# %% [markdown]
# ## Data Loading and Preparation
# - This function loads data from individual station files and groups them by state.

# %%
def load_and_prepare_data(data_dir, metadata_file):
    """
    Load data from individual station files and group by state
    
    Parameters:
    - data_dir: Directory containing station_<id>_aqi_data.csv files
    - metadata_file: Path to metadata.csv with station information
    
    Returns:
    - Dictionary with state names as keys and DataFrames as values
    """
    # Load metadata
    metadata = pd.read_csv(metadata_file)
    print(f"Loaded metadata with {len(metadata)} stations")
    
    # Initialize dictionary to store dataframes by state
    state_data = {}
    
    # Get list of all CSV files
    csv_files = [f for f in os.listdir(data_dir) if f.startswith('station_') and f.endswith('_aqi_data.csv')]
    print(f"Found {len(csv_files)} station data files")
    
    for file in csv_files:
        # Extract station_id from filename
        station_id = file.split('_')[1]
        
        # Find state for this station
        station_info = metadata[metadata['id'] == int(station_id)]
        
        if len(station_info) == 0:
            print(f"Warning: No metadata found for station {station_id}")
            continue
            
        state = station_info['state'].iloc[0]
        
        # Load station data
        df = pd.read_csv(os.path.join(data_dir, file))
        
        # Add station metadata
        df['id'] = station_id
        df['state'] = state
        
        # Convert date to datetime
        if 'date' in df.columns:
            df['date'] = pd.to_datetime(df['date'])
        
        # Add to state_data dictionary
        if state not in state_data:
            state_data[state] = []
        
        state_data[state].append(df)
    
    # Combine all dataframes for each state
    for state in state_data:
        state_data[state] = pd.concat(state_data[state], ignore_index=True)
        print(f"State {state}: {len(state_data[state])} records")
    
    return state_data

# %% [markdown]
# ## Sequence Creation for LSTM
# - This function creates sequences of data for LSTM input.

# %%
def create_sequences(data, sequence_length=SEQUENCE_LENGTH):
    """
    Create sequences for LSTM input
    
    Parameters:
    - data: DataFrame with pollutant data
    - sequence_length: Number of days to use for prediction
    
    Returns:
    - X: Input sequences
    - y: Target values
    """
    X, y = [], []
    
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    
    return np.array(X), np.array(y)

# %% [markdown]
# ## Data Preprocessing
# - This function preprocesses data for a single state, including handling missing values, scaling, and creating sequences.

# %%
def preprocess_state_data(state_df):
    """
    Preprocess data for a single state
    
    Parameters:
    - state_df: DataFrame with pollutant data for a state
    
    Returns:
    - Dictionary with training and testing data
    """
    # Sort by date
    if 'date' in state_df.columns:
        state_df = state_df.sort_values('date')
    
    # Select only pollutant columns
    pollutant_data = state_df[POLLUTANTS].copy()
    
    # Handle missing values
    pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
    
    # Scale the data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(pollutant_data)
    
    # Create sequences
    X, y = create_sequences(scaled_data)
    
    # Split into training and testing sets
    split_idx = int(len(X) * (1 - TEST_SPLIT))
    
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]
    
    return {
        'X_train': X_train,
        'y_train': y_train,
        'X_test': X_test,
        'y_test': y_test,
        'scaler': scaler
    }

# %% [markdown]
# ## LSTM Model Architecture
# - This function builds the LSTM model architecture for pollutant prediction.

# %%
def build_lstm_model(input_shape):
    """
    Build LSTM model for pollutant prediction
    
    Parameters:
    - input_shape: Shape of input sequences
    
    Returns:
    - Compiled LSTM model
    """
    model = Sequential([
        LSTM(MODEL_PARAMS['lstm_units'], return_sequences=True, input_shape=input_shape),
        Dropout(MODEL_PARAMS['dropout_rate']),
        LSTM(MODEL_PARAMS['lstm_units']),
        Dropout(MODEL_PARAMS['dropout_rate']),
        Dense(len(POLLUTANTS))  # Output layer with one neuron per pollutant
    ])
    
    model.compile(optimizer='adam', loss='mse')
    return model

# %% [markdown]
# ## Model Training Function
# This function trains an LSTM model for a single state and evaluates its performance.

# %%
def train_state_model(state_name, preprocessed_data):
    """
    Train LSTM model for a single state
    
    Parameters:
    - state_name: Name of the state
    - preprocessed_data: Dictionary with training and testing data
    
    Returns:
    - Dictionary with model, history, and evaluation metrics
    """
    print(f"\nTraining model for state: {state_name}")
    
    X_train = preprocessed_data['X_train']
    y_train = preprocessed_data['y_train']
    X_test = preprocessed_data['X_test']
    y_test = preprocessed_data['y_test']
    
    # Build model
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_lstm_model(input_shape)
    
    # Define early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=MODEL_PARAMS['patience'],
        restore_best_weights=True
    )
    
    # Train model
    history = model.fit(
        X_train, y_train,
        epochs=MODEL_PARAMS['epochs'],
        batch_size=MODEL_PARAMS['batch_size'],
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Inverse transform predictions and actual values
    scaler = preprocessed_data['scaler']
    y_test_orig = scaler.inverse_transform(y_test)
    y_pred_orig = scaler.inverse_transform(y_pred)
    
    # Calculate metrics
    metrics = {}
    for i, pollutant in enumerate(POLLUTANTS):
        metrics[pollutant] = {
            'mse': mean_squared_error(y_test_orig[:, i], y_pred_orig[:, i]),
            'rmse': np.sqrt(mean_squared_error(y_test_orig[:, i], y_pred_orig[:, i])),
            'mae': mean_absolute_error(y_test_orig[:, i], y_pred_orig[:, i]),
            'r2': r2_score(y_test_orig[:, i], y_pred_orig[:, i])
        }
    
    return {
        'model': model,
        'history': history,
        'y_test': y_test_orig,
        'y_pred': y_pred_orig,
        'metrics': metrics,
        'scaler': scaler
    }

# %% [markdown]
# ## Data Loading Example
# - Let's load the data using the functions defined above.

# %%
# Define paths
data_dir = "/kaggle/input/india-aqi-data-2020-25/final_data/india_aqi_data_withcityname"  # Update with your data directory
metadata_file = "/kaggle/input/india-aqi-data-2020-25/final_data/metadata.csv"  # Update with your metadata file path
    
# Load and group data by state
state_data = load_and_prepare_data(data_dir, metadata_file)
# Out:
# Loaded metadata with 662 stations
# Found 662 station data files
# State Delhi: 113040 records
# State Karnataka: 80070 records
# State Telangana: 29830 records
# State Gujarat: 28260 records
# State Rajasthan: 75360 records
# State Haryana: 61179 records
# State Tamil Nadu: 69080 records
# State Karanataka: 1570 records
# State Kerala: 14130 records
# State Uttar Pradesh: 103620 records
# State Maharashtra: 158570 records
# State Madhya Pradesh: 51810 records
# State Bihar: 61230 records
# State West Bengal: 47100 records
# State Punjab: 14130 records
# State Chhattisgarh: 20410 records
# State Meghalaya: 4710 records
# State Odisha: 29830 records
# State Tripura: 3140 records
# State Assam: 15700 records
# State Andhra Pradesh: 23550 records
# State Jharkhand: 4710 records
# State Manipur: 6280 records
# State Puducherry: 1570 records
# State Chandigarh: 4710 records
# State Nagaland: 1570 records
# State Sikkim: 3140 records
# State Mizoram: 1570 records
# State Uttarakhand: 4710 records
# State Himachal Pradesh: 1570 records
# State Jammu and Kashmir: 1570 records
# State Arunachal Pradesh: 1570 records

# %% [markdown]
# ## Model Training Example
# - Training a model for each state.

# %%
import json
# Create models directory if it doesn't exist
models_dir = "/kaggle/working/trained_models"
os.makedirs(models_dir, exist_ok=True)

# Train models for each state
state_results = {}
    
for state, df in state_data.items():
        # Skip states with insufficient data
        if len(df) < SEQUENCE_LENGTH * 2:
            print(f"Skipping state {state} due to insufficient data")
            continue
        
        # Create state directory for model artifacts
        state_model_dir = os.path.join(models_dir, state)
        os.makedirs(state_model_dir, exist_ok=True)
        
        # Preprocess data
        preprocessed_data = preprocess_state_data(df)
        
        # Train model
        state_results[state] = train_state_model(state, preprocessed_data)
        
        # Save model
        model_path = os.path.join(state_model_dir, f"{state}_model.h5")
        state_results[state]['model'].save(model_path)
        print(f"Model saved to {model_path}")
        
        # Save scaler using pickle
        import pickle
        scaler_path = os.path.join(state_model_dir, f"{state}_scaler.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(state_results[state]['scaler'], f)
        print(f"Scaler saved to {scaler_path}")
        
        # Save model configuration as JSON
        model_config = {
            'pollutants': POLLUTANTS,
            'sequence_length': SEQUENCE_LENGTH,
            'model_params': MODEL_PARAMS,
            'training_date': str(pd.Timestamp.now())
        }
        
        config_path = os.path.join(state_model_dir, f"{state}_config.json")
        with open(config_path, 'w') as f:
            json.dump(model_config, f, indent=4)
        print(f"Model configuration saved to {config_path}")
# Out:
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# Training model for state: Delhi
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.0126 - val_loss: 0.0041
# Epoch 2/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 3/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 4/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 5/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 6/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 7/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 8/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 9/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 10/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 11/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 12/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 13/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 14/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 15/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 16/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 17/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 18/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 19/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 20/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 21/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 22/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 23/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 24/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 25/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 26/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 27/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 28/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 29/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 30/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 31/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 32/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 33/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 34/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 35/50
# 2261/2261 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# 707/707 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Delhi/Delhi_model.h5
# Scaler saved to /kaggle/working/trained_models/Delhi/Delhi_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Delhi/Delhi_config.json
#
# Training model for state: Karnataka
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0123 - val_loss: 0.0027
# Epoch 2/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 3/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 4/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 5/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 6/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 7/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 8/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 9/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 10/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 11/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 12/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 13/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 14/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 15/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 16/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 17/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 18/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 19/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 20/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 21/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 22/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 23/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 24/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 25/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 26/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 27/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 28/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 29/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 30/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 31/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 32/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 33/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 34/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 35/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 36/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 37/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 38/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 39/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 40/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 41/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 42/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 43/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 44/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 45/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 46/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 47/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 48/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 49/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 50/50
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Karnataka/Karnataka_model.h5
# Scaler saved to /kaggle/working/trained_models/Karnataka/Karnataka_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Karnataka/Karnataka_config.json
#
# Training model for state: Telangana
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0196 - val_loss: 0.0035
# Epoch 2/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0063 - val_loss: 0.0031
# Epoch 3/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 4/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0051 - val_loss: 0.0030
# Epoch 5/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 6/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 7/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 8/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 9/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 10/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 11/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 12/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 13/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 14/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 15/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 16/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 17/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 18/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 19/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 20/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 21/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 22/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 23/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 24/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 25/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 26/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 27/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 28/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 29/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 30/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 31/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 32/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 33/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 34/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 35/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 36/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 37/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 38/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 39/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 40/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 41/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 42/50
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0039 - val_loss: 0.0029
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Telangana/Telangana_model.h5
# Scaler saved to /kaggle/working/trained_models/Telangana/Telangana_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Telangana/Telangana_config.json
#
# Training model for state: Gujarat
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0242 - val_loss: 0.0058
# Epoch 2/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 3/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 4/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 5/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 6/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 7/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 8/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 9/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 10/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 11/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 12/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 13/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 14/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 15/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 16/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 17/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 18/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 19/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 20/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 21/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 22/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 23/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 24/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 25/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 26/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 27/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 28/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 29/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 30/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 31/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 32/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 33/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 34/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 35/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 36/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 37/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 38/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 39/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 40/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 41/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 42/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 43/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 44/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 45/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 46/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 47/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 48/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 49/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 50/50
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0043 - val_loss: 0.0051
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Gujarat/Gujarat_model.h5
# Scaler saved to /kaggle/working/trained_models/Gujarat/Gujarat_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Gujarat/Gujarat_config.json
#
# Training model for state: Rajasthan
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0111 - val_loss: 0.0021
# Epoch 2/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 3/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 4/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 5/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 6/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 7/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 8/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 9/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 10/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 11/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 12/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 13/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 14/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 15/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 16/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 17/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 18/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 19/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 20/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 21/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 22/50
# 1508/1508 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Rajasthan/Rajasthan_model.h5
# Scaler saved to /kaggle/working/trained_models/Rajasthan/Rajasthan_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Rajasthan/Rajasthan_config.json
#
# Training model for state: Haryana
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0106 - val_loss: 0.0033
# Epoch 2/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 3/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 4/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 5/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 6/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 7/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 8/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 9/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 10/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 11/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 12/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 13/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 14/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 15/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 16/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 17/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 18/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 19/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 20/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 21/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 22/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 23/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 24/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 25/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 26/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 27/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 28/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 29/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 30/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 31/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 32/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 33/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 34/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 35/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 36/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 37/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 38/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 39/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 40/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 41/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 42/50
# 1224/1224 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Haryana/Haryana_model.h5
# Scaler saved to /kaggle/working/trained_models/Haryana/Haryana_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Haryana/Haryana_config.json
#
# Training model for state: Tamil Nadu
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0149 - val_loss: 0.0037
# Epoch 2/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 3/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 4/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 5/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 6/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 7/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 8/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 9/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 10/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 11/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 12/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 13/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 14/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 15/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 16/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 17/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 18/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 19/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 20/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 21/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 22/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 23/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 24/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 25/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 26/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 27/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 28/50
# 1382/1382 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0043 - val_loss: 0.0035
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Tamil Nadu/Tamil Nadu_model.h5
# Scaler saved to /kaggle/working/trained_models/Tamil Nadu/Tamil Nadu_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Tamil Nadu/Tamil Nadu_config.json
#
# Training model for state: Karanataka
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1448 - val_loss: 0.0149
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0227 - val_loss: 0.0099
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0196 - val_loss: 0.0099
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0171 - val_loss: 0.0091
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156 - val_loss: 0.0090
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152 - val_loss: 0.0090
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - val_loss: 0.0089
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - val_loss: 0.0085
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - val_loss: 0.0086
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - val_loss: 0.0084
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - val_loss: 0.0083
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - val_loss: 0.0078
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0113 - val_loss: 0.0077
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0077
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0108 - val_loss: 0.0077
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0106 - val_loss: 0.0072
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0109 - val_loss: 0.0072
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0072
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0070
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - val_loss: 0.0068
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0070
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0064
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0066
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0061
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091 - val_loss: 0.0060
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0060
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - val_loss: 0.0062
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - val_loss: 0.0065
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0061
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0062
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - val_loss: 0.0059
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0058
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0057
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - val_loss: 0.0056
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0055
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - val_loss: 0.0055
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0055
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - val_loss: 0.0056
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - val_loss: 0.0054
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Model saved to /kaggle/working/trained_models/Karanataka/Karanataka_model.h5
# Scaler saved to /kaggle/working/trained_models/Karanataka/Karanataka_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Karanataka/Karanataka_config.json
#
# Training model for state: Kerala
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0442 - val_loss: 0.0051
# Epoch 2/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0086 - val_loss: 0.0048
# Epoch 3/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 4/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 5/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0065 - val_loss: 0.0048
# Epoch 6/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 7/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 8/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 9/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 10/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0054 - val_loss: 0.0047
# Epoch 11/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0054 - val_loss: 0.0047
# Epoch 12/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 13/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 14/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 15/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 16/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 17/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 18/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 19/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 20/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 21/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 22/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 23/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 24/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 25/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 26/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 27/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 28/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 29/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 30/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 31/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 32/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 33/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 34/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 35/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 36/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 37/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 38/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 39/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 40/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 41/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 42/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 43/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 44/50
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Model saved to /kaggle/working/trained_models/Kerala/Kerala_model.h5
# Scaler saved to /kaggle/working/trained_models/Kerala/Kerala_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Kerala/Kerala_config.json
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# Training model for state: Uttar Pradesh
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 2/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 3/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 4/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 5/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 6/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 7/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 8/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 9/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 10/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 11/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 12/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 13/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 14/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 15/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 16/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 17/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 18/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 19/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 20/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 21/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 22/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 23/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 24/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 25/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 26/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 27/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 28/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 29/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 30/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 31/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 32/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 33/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 34/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 35/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 36/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 37/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 38/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 39/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 40/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 41/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 42/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 43/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 44/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 45/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 46/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 47/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 48/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 49/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 50/50
# 2073/2073 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0035 - val_loss: 0.0037
# 648/648 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Model saved to /kaggle/working/trained_models/Uttar Pradesh/Uttar Pradesh_model.h5
# Scaler saved to /kaggle/working/trained_models/Uttar Pradesh/Uttar Pradesh_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Uttar Pradesh/Uttar Pradesh_config.json
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# Training model for state: Maharashtra
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - loss: 0.0104 - val_loss: 0.0064
# Epoch 2/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 3/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 4/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 5/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 6/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 7/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 8/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 9/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 10/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 11/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 12/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 13/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 14/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 15/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 16/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 17/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 18/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 19/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 20/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 21/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 22/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 23/50
# 3172/3172 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - loss: 0.0055 - val_loss: 0.0063
# 992/992 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Model saved to /kaggle/working/trained_models/Maharashtra/Maharashtra_model.h5
# Scaler saved to /kaggle/working/trained_models/Maharashtra/Maharashtra_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Maharashtra/Maharashtra_config.json
#
# Training model for state: Madhya Pradesh
# ...
# Epoch 49/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 50/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - val_loss: 0.0054
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Model saved to /kaggle/working/trained_models/Uttarakhand/Uttarakhand_model.h5
# Scaler saved to /kaggle/working/trained_models/Uttarakhand/Uttarakhand_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Uttarakhand/Uttarakhand_config.json
#
# Training model for state: Himachal Pradesh
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1626 - val_loss: 0.0144
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0218 - val_loss: 0.0121
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0180 - val_loss: 0.0117
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156 - val_loss: 0.0114
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0157 - val_loss: 0.0115
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0154 - val_loss: 0.0103
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - val_loss: 0.0100
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - val_loss: 0.0100
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - val_loss: 0.0096
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - val_loss: 0.0100
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - val_loss: 0.0098
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - val_loss: 0.0097
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0094
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0113 - val_loss: 0.0099
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0093
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0109 - val_loss: 0.0094
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108 - val_loss: 0.0093
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 0.0090
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0091
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0091
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0090
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 0.0091
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0089
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - val_loss: 0.0087
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - val_loss: 0.0087
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - val_loss: 0.0086
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0096 - val_loss: 0.0085
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0090
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0087
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0084
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0084
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0081
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0079
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0078
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 0.0079
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0076
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0077
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Model saved to /kaggle/working/trained_models/Himachal Pradesh/Himachal Pradesh_model.h5
# Scaler saved to /kaggle/working/trained_models/Himachal Pradesh/Himachal Pradesh_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Himachal Pradesh/Himachal Pradesh_config.json
#
# Training model for state: Jammu and Kashmir
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1338 - val_loss: 0.0173
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - val_loss: 0.0125
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - val_loss: 0.0100
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - val_loss: 0.0095
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0163 - val_loss: 0.0101
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0154 - val_loss: 0.0103
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0157 - val_loss: 0.0093
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - val_loss: 0.0092
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - val_loss: 0.0095
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0144 - val_loss: 0.0093
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - val_loss: 0.0091
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - val_loss: 0.0098
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - val_loss: 0.0090
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - val_loss: 0.0090
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - val_loss: 0.0092
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0121 - val_loss: 0.0087
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - val_loss: 0.0089
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - val_loss: 0.0088
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0110 - val_loss: 0.0085
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - val_loss: 0.0085
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0114 - val_loss: 0.0093
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0083
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0081
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0080
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0106 - val_loss: 0.0080
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - val_loss: 0.0091
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 0.0084
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0077
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103 - val_loss: 0.0081
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - val_loss: 0.0075
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0075
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0077
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0076
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - val_loss: 0.0074
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0072
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0073
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - val_loss: 0.0076
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - val_loss: 0.0074
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - val_loss: 0.0074
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - val_loss: 0.0072
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - val_loss: 0.0072
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0072
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0073
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - val_loss: 0.0072
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0075
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0072
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Model saved to /kaggle/working/trained_models/Jammu and Kashmir/Jammu and Kashmir_model.h5
# Scaler saved to /kaggle/working/trained_models/Jammu and Kashmir/Jammu and Kashmir_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Jammu and Kashmir/Jammu and Kashmir_config.json
#
# Training model for state: Arunachal Pradesh
# Epoch 1/50
# <ipython-input-14-380b447d3391>:122: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollutant_data = pollutant_data.fillna(method='ffill').fillna(method='bfill')
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1854 - val_loss: 0.0130
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0236 - val_loss: 0.0080
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0204 - val_loss: 0.0075
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0176 - val_loss: 0.0071
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161 - val_loss: 0.0065
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - val_loss: 0.0062
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - val_loss: 0.0066
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - val_loss: 0.0063
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - val_loss: 0.0065
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - val_loss: 0.0065
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - val_loss: 0.0060
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - val_loss: 0.0063
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - val_loss: 0.0063
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0114 - val_loss: 0.0063
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - val_loss: 0.0056
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0060
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0110 - val_loss: 0.0058
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0058
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0056
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - val_loss: 0.0055
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0056
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112 - val_loss: 0.0054
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0054
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0106 - val_loss: 0.0053
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103 - val_loss: 0.0055
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - val_loss: 0.0054
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - val_loss: 0.0057
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - val_loss: 0.0056
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0055
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 0.0054
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - val_loss: 0.0054
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - val_loss: 0.0058
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - val_loss: 0.0051
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - val_loss: 0.0051
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - val_loss: 0.0051
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0051
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0050
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0048
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - val_loss: 0.0051
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0050
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0052
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 0.0050
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0053
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0049
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 0.0048
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - val_loss: 0.0049
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0052
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0049
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - val_loss: 0.0048
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0048
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Model saved to /kaggle/working/trained_models/Arunachal Pradesh/Arunachal Pradesh_model.h5
# Scaler saved to /kaggle/working/trained_models/Arunachal Pradesh/Arunachal Pradesh_scaler.pkl
# Model configuration saved to /kaggle/working/trained_models/Arunachal Pradesh/Arunachal Pradesh_config.json

# %% [markdown]
# ## Model Evaluation
#
# - Evaluation of each trained model for each state and save the evaluation results

# %%
def evaluate_and_visualize(state_results, output_dir="evaluation_results"):
    """
    Evaluate models and visualize results, saving all outputs to structured directories
    
    Parameters:
    - state_results: Dictionary with results for each state
    - output_dir: Directory to save evaluation results
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Create directory for plots
    plots_dir = os.path.join(output_dir, "plots")
    os.makedirs(plots_dir, exist_ok=True)
    
    # Create directory for metrics
    metrics_dir = os.path.join(output_dir, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)
    
    # Create summary dataframe for metrics across states
    metrics_summary = []
    
    for state, result in state_results.items():
        # Create state-specific directories
        state_dir = os.path.join(output_dir, state)
        os.makedirs(state_dir, exist_ok=True)
        
        # Save state metrics to CSV
        state_metrics = []
        for pollutant, metrics in result['metrics'].items():
            metrics_summary.append({
                'state': state,
                'pollutant': pollutant,
                'mse': metrics['mse'],
                'rmse': metrics['rmse'],
                'mae': metrics['mae'],
                'r2': metrics['r2']
            })
            state_metrics.append({
                'pollutant': pollutant,
                'mse': metrics['mse'],
                'rmse': metrics['rmse'],
                'mae': metrics['mae'],
                'r2': metrics['r2']
            })
        
        # Save state-specific metrics
        pd.DataFrame(state_metrics).to_csv(os.path.join(state_dir, f"{state}_metrics.csv"), index=False)
        
        # Plot and save comparison of predicted vs actual for each pollutant in the state
        plt.figure(figsize=(20, 15))
        
        for i, pollutant in enumerate(POLLUTANTS):
            plt.subplot(4, 2, i+1)
            
            # Plot actual vs predicted
            plt.plot(result['y_test'][:, i], label='Actual', alpha=0.7)
            plt.plot(result['y_pred'][:, i], label='Predicted', alpha=0.7)
            
            plt.title(f'{state} - {pollutant}')
            plt.xlabel('Time')
            plt.ylabel('Value')
            plt.legend()
            
            # Save individual pollutant plot
            plt.figure(figsize=(10, 6))
            plt.plot(result['y_test'][:, i], label='Actual', alpha=0.7)
            plt.plot(result['y_pred'][:, i], label='Predicted', alpha=0.7)
            plt.title(f'{state} - {pollutant}')
            plt.xlabel('Time')
            plt.ylabel('Value')
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(state_dir, f"{state}_{pollutant}_prediction.png"))
            plt.close()
        
        plt.tight_layout()
        plt.savefig(os.path.join(state_dir, f"{state}_all_predictions.png"))
        plt.savefig(os.path.join(plots_dir, f"{state}_all_predictions.png"))
        plt.close()
        
        # Plot and save training history
        plt.figure(figsize=(10, 6))
        plt.plot(result['history'].history['loss'], label='Training Loss')
        plt.plot(result['history'].history['val_loss'], label='Validation Loss')
        plt.title(f'{state} - Training History')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.savefig(os.path.join(state_dir, f"{state}_training_history.png"))
        plt.savefig(os.path.join(plots_dir, f"{state}_training_history.png"))
        plt.close()
        
        # Save actual vs predicted values as CSV
        pred_df = pd.DataFrame()
        for i, pollutant in enumerate(POLLUTANTS):
            pred_df[f"{pollutant}_actual"] = result['y_test'][:, i]
            pred_df[f"{pollutant}_predicted"] = result['y_pred'][:, i]
        
        pred_df.to_csv(os.path.join(state_dir, f"{state}_predictions.csv"), index=False)
    
    # Create and save overall metrics dataframe
    metrics_df = pd.DataFrame(metrics_summary)
    metrics_df.to_csv(os.path.join(metrics_dir, "all_metrics.csv"), index=False)
    
    # Save average metrics by pollutant - FIX: explicitly select numeric columns only
    numeric_columns = ['mse', 'rmse', 'mae', 'r2']
    avg_metrics = metrics_df.groupby('pollutant')[numeric_columns].mean()
    avg_metrics.to_csv(os.path.join(metrics_dir, "avg_metrics_by_pollutant.csv"))
    print("\nAverage metrics across all states:")
    print(avg_metrics)
    
    # Save average metrics by state - FIX: explicitly select numeric columns only
    state_avg_metrics = metrics_df.groupby('state')[numeric_columns].mean()
    state_avg_metrics.to_csv(os.path.join(metrics_dir, "avg_metrics_by_state.csv"))
    
    # Create and save heatmap of R² scores by pollutant and state
    r2_matrix = metrics_df.pivot(index='state', columns='pollutant', values='r2')
    r2_matrix.to_csv(os.path.join(metrics_dir, "r2_matrix.csv"))
    
    plt.figure(figsize=(12, 10))
    sns.heatmap(r2_matrix, annot=True, cmap='YlGnBu', fmt='.2f')
    plt.title('R² Score by State and Pollutant')
    plt.tight_layout()
    plt.savefig(os.path.join(plots_dir, 'r2_heatmap.png'))
    plt.close()
    
    # Create and save heatmaps for other metrics
    for metric in ['mse', 'rmse', 'mae']:
        metric_matrix = metrics_df.pivot(index='state', columns='pollutant', values=metric)
        metric_matrix.to_csv(os.path.join(metrics_dir, f"{metric}_matrix.csv"))
        
        plt.figure(figsize=(12, 10))
        sns.heatmap(metric_matrix, annot=True, cmap='YlGnBu', fmt='.2f')
        plt.title(f'{metric.upper()} by State and Pollutant')
        plt.tight_layout()
        plt.savefig(os.path.join(plots_dir, f'{metric}_heatmap.png'))
        plt.close()
    
    # Generate a summary report in HTML format
    html_report = f"""
    <html>
    <head>
        <title>Air Pollutant Prediction Results</title>
        <style>
            body {{ font-family: Arial, sans-serif; margin: 20px; }}
            h1, h2, h3 {{ color: #2c3e50; }}
            table {{ border-collapse: collapse; width: 100%; margin-bottom: 20px; }}
            th, td {{ border: 1px solid #ddd; padding: 8px; text-align: left; }}
            th {{ background-color: #f2f2f2; }}
            tr:nth-child(even) {{ background-color: #f9f9f9; }}
            .metric-summary {{ margin-bottom: 30px; }}
            img {{ max-width: 100%; height: auto; margin: 10px 0; }}
        </style>
    </head>
    <body>
        <h1>Air Pollutant Prediction - Model Evaluation Report</h1>
        <p>Generated on {pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')}</p>
        
        <div class="metric-summary">
            <h2>Average Metrics by Pollutant</h2>
            {avg_metrics.to_html()}
        </div>
        
        <div class="metric-summary">
            <h2>Average Metrics by State</h2>
            {state_avg_metrics.to_html()}
        </div>
        
        <h2>Performance Heatmaps</h2>
        <p>R² Score by State and Pollutant:</p>
        <img src="plots/r2_heatmap.png" alt="R² Heatmap">
        
        <p>RMSE by State and Pollutant:</p>
        <img src="plots/rmse_heatmap.png" alt="RMSE Heatmap">
        
        <h2>State-wise Results</h2>
    """
    
    # Add links to individual state results
    for state in state_results.keys():
        html_report += f"""
        <h3>{state}</h3>
        <p><a href="{state}/{state}_metrics.csv">Download Metrics CSV</a></p>
        <p><a href="{state}/{state}_predictions.csv">Download Predictions CSV</a></p>
        <p>All Pollutants Prediction:</p>
        <img src="{state}/{state}_all_predictions.png" alt="{state} Predictions">
        <p>Training History:</p>
        <img src="{state}/{state}_training_history.png" alt="{state} Training History">
        """
    
    html_report += """
    </body>
    </html>
    """
    
    with open(os.path.join(output_dir, "evaluation_report.html"), "w") as f:
        f.write(html_report)
    
    print(f"\nEvaluation results saved to {output_dir}/")
    print(f"Summary report generated at {output_dir}/evaluation_report.html")

# %%
evaluate_and_visualize(state_results, output_dir="/kaggle/working/all_aqi_prediction_results")
# Out:
# Average metrics across all states:
#                      mse        rmse         mae        r2
# pollutant
# co         105177.476211  238.499360  166.616218  0.556043
# nh3            23.303343    4.011266    2.729032  0.502956
# no             23.908908    3.185542    1.818769  0.195052
# no2          1186.300616   34.377017    9.665001  0.087585
# o3            394.847555   19.354378   12.513625  0.490102
# pm10         1415.324934   30.462693   19.899038  0.696800
# pm2_5         933.988980   25.003578   16.635395  0.747214
# so2           140.841294    8.459181    6.302401  0.316944
#
# Evaluation results saved to /kaggle/working/all_aqi_prediction_results/
# Summary report generated at /kaggle/working/all_aqi_prediction_results/evaluation_report.html

# %%
import shutil

# Define the folder path and the output zip file path (without extension)
folder_path = "/kaggle/working/all_aqi_prediction_results"
zip_basename = folder_path  # This will create "aqi_prediction_results.zip"

# Zip the folder
shutil.make_archive(zip_basename, 'zip', folder_path)

print("Folder zipped successfully!")
# Out:
# Folder zipped successfully!

# %%
import shutil

# Define the folder path and the output zip file path (without extension)
folder_path = "/kaggle/working/trained_models"
zip_basename = folder_path  # This will create "aqi_prediction_results.zip"

# Zip the folder
shutil.make_archive(zip_basename, 'zip', folder_path)

print("Folder zipped successfully!")
# Out:
# Folder zipped successfully!

# %% [markdown]
# ## Function to load the saved model and predict for any sequence of new data

# %%
def load_model_and_predict(state, new_data, models_dir="trained_models"):
    """
    Load a trained model and its scaler for a specific state and make predictions
    
    Parameters:
    - state: State name for which to load the model
    - new_data: DataFrame with new data for prediction
    - models_dir: Directory where models are saved
    
    Returns:
    - DataFrame with predictions
    """
    import pickle
    import json
    import numpy as np
    import pandas as pd
    import tensorflow as tf
    
    # Paths
    state_model_dir = os.path.join(models_dir, state)
    model_path = os.path.join(state_model_dir, f"{state}_model.h5")
    scaler_path = os.path.join(state_model_dir, f"{state}_scaler.pkl")
    config_path = os.path.join(state_model_dir, f"{state}_config.json")
    
    # Load model
    model = tf.keras.models.load_model(model_path)
    print(f"Loaded model from {model_path}")
    
    # Load scaler
    with open(scaler_path, 'rb') as f:
        scaler = pickle.load(f)
    print(f"Loaded scaler from {scaler_path}")
    
    # Load configuration
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    pollutants = config['pollutants']
    sequence_length = config['sequence_length']
    
    # Prepare new data
    # Extract only pollutant columns
    input_data = new_data[pollutants].copy()
    
    # Handle missing values
    input_data = input_data.fillna(method='ffill').fillna(method='bfill')
    
    # Scale the data
    scaled_input = scaler.transform(input_data)
    
    # Create sequences
    X = []
    for i in range(len(scaled_input) - sequence_length + 1):
        X.append(scaled_input[i:i+sequence_length])
    
    X = np.array(X)
    
    # Make predictions
    scaled_predictions = model.predict(X)
    
    # Inverse transform predictions
    predictions = scaler.inverse_transform(scaled_predictions)
    
    # Create result DataFrame
    result_df = pd.DataFrame()
    
    if 'date' in new_data.columns:
        # Shift dates forward by sequence_length to align with predictions
        result_df['date'] = new_data['date'].iloc[sequence_length:].reset_index(drop=True)
    
    # Add predictions for each pollutant
    for i, pollutant in enumerate(pollutants):
        result_df[f'{pollutant}_predicted'] = predictions[:, i]
    
    return result_df

# Example usage:
"""
# Load new data for a specific state
new_data = pd.read_csv('path/to/new_data.csv')

# Make predictions
predictions = load_model_and_predict('Maharashtra', new_data)
print(predictions.head())

# Plot predictions
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
for i, pollutant in enumerate(['pm2_5', 'pm10', 'so2', 'no', 'no2', 'nh3', 'o3', 'co']):
    plt.subplot(4, 2, i+1)
    plt.plot(predictions['date'], predictions[f'{pollutant}_predicted'])
    plt.title(f'Predicted {pollutant}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
"""
